# %%
# Important Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# load dataset
data=pd.read_csv("C:\\Users\\keshav\\OneDrive\\Desktop\\Project_Files\\Mobile Price Prediction\\mobile_price.csv")

# %%
# View fist 5 rows of the dataset
data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
# View the last 5 rows of the dataset
data.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
# describe the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
# Chech dimension of the data
data.shape
# Out:
# (2000, 21)

# %%
# Summarze the dataset
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
# let check the null values in the dataset
data.isnull().sum().sum()
# Out:
# 0

# %%
# Count the price values in the data
data['price_range'].value_counts()
# Out:
# price_range
# 1    500
# 2    500
# 3    500
# 0    500
# Name: count, dtype: int64

# %% [markdown]
# ## EDA

# %%
# Bivarite Analysis
# dependent vs continous independent variables

sns.boxplot(y=data['dual_sim'],x=data['price_range'])
plt.title('Price Range according to Dual Sim')
plt.xlabel('Price Range')
plt.ylabel('Dual Sim Phone')
plt.show()

# %%
# Ram and Battery Power according to price range 
sns.scatterplot(x=data['battery_power'],y=data['ram'],hue=data['price_range'], palette=('deep'))
plt.title('Ram and Battery according to Price Range')
plt.xlabel('Batter Power mah')
plt.ylabel('Ram')
plt.show()

# %%
# let see the weight and height of the phone effectiong price 
sns.histplot(x=data['px_height'],y=data['px_width'], hue=data['price_range'],palette=('bright'))
# Out:
# <Axes: xlabel='px_height', ylabel='px_width'>

# %% [markdown]
# ## Modeling

# %%
# Lets us convert into dumpy variables
df=pd.get_dummies(data)

# %%
# let chech dimension 
print(f"Dumpy dataset rows and columns :",df.shape)
# Out:
# Dumpy dataset rows and columns : (2000, 21)

# %%
# split the dataset
from sklearn.model_selection import train_test_split

# %%
trainDf,testDf=train_test_split(df,train_size=0.7,random_state=2410)

# %%
# let us split into dependent and independent variables
trainX=trainDf.drop(["price_range"],axis=1)
trainY=trainDf["price_range"]
testX=testDf.drop(["price_range"],axis=1)
testY=testDf["price_range"]

# %%
# Modeling 
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier().fit(trainX,trainY)

# %%
# Prediction
testpredict=rf.predict(testX)

# %%
# Evaluation
from sklearn.metrics import confusion_matrix,classification_report,r2_score

# %%
print(confusion_matrix(testY,testpredict))
# Out:
# [[132  12   0   0]
#  [ 18 127  10   0]
#  [  0  12 134  10]
#  [  0   0   7 138]]

# %%
print(classification_report(testY,testpredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       144
#            1       0.84      0.82      0.83       155
#            2       0.89      0.86      0.87       156
#            3       0.93      0.95      0.94       145
#
#     accuracy                           0.89       600
#    macro avg       0.89      0.89      0.89       600
# weighted avg       0.88      0.89      0.88       600

# %%
print(f'r2 score for a model which predicts is:',round(r2_score(testY,testpredict)))
# Out:
# r2 score for a model which predicts is: 1

# %%
# Training the model the taining set
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(trainX,trainY)
# Out:
# GaussianNB()

# %%
# Making prediction using datasst
y_predict=gnb.predict(testX)

# %%
# Modeling 
from sklearn.metrics import accuracy_score

# %%
accuracy=print(f"Gaussian Naive Banyes Accuracy Score", round(accuracy_score(testY, y_predict)*100))
# Out:
# Gaussian Naive Banyes Accuracy Score 82

# %%
labels = ["low cost", "medium cost", "high cost", "very high cost"]

from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(testY, testpredict)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot();
